# %%
import torch
from torch import nn
from d2l import torch as d2l

batch_size = 256
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)
# Out:
# C:\ProgramData\Anaconda3\envs\ML\lib\site-packages\torchvision\datasets\mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ..\torch\csrc\utils\tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %% [markdown]
# ## 1. Initializing Model Parameters
# ![image.png](attachment:image.png)

# %%
# PyTorch does not implicitly reshape the inputs. Thus we define the flatten
# layer to reshape the inputs before the linear layer in our network
net = nn.Sequential(nn.Flatten(), nn.Linear(784, 10))

def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=0.01)
        
net.apply(init_weights)
# Out:
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=10, bias=True)
# )

# %% [markdown]
# ## 2. Softmax Regression
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
loss = nn.CrossEntropyLoss()

# %% [markdown]
# ## 3. Optimization Algorithm

# %%
trainer = torch.optim.SGD(net.parameters(), lr=0.1)

# %% [markdown]
# ## 4. Training

# %%
epochs = 10
d2l.train_ch3(net, train_iter, test_iter, loss, epochs, trainer)
